# %% [markdown]
# File Handlings

# %% [markdown]
# ```
# file1 = open('filepath.format', 'mode')
#
# 'a' for append
#
# 'w' for write
#
# 'r' for read
#
# file1.name
#
# file1.mode
#
# file1.close()
#
# with open(...) as file1 -> not need close file
#
# file1.read()
#
# file1.readline()
#
# file1.readlines(n)
#
# file1.closed()
#
# file1.write('something')
#
# or loops
# ```
